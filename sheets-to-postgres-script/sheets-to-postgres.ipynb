# %%
import os
import pandas as pd
import gspread
import googlemaps
import psycopg2
from dotenv import load_dotenv
from sqlalchemy import create_engine

# %%
load_dotenv()

SERVICE_ACCOUNT_JSON = os.getenv('SERVICE_ACCOUNT_JSON')
SHEET_KEY = os.getenv('SHEET_KEY')
MAPS_API = os.getenv('MAPS_API')
CONN_STR = os.getenv('CONN_STR')

# %%
# Access Google Sheets
gc = gspread.service_account(filename=SERVICE_ACCOUNT_JSON)

sh = gc.open_by_key(SHEET_KEY)

wksh = sh.sheet1

# %%
# Convert Sheets to Pandas Dataframe
df = pd.DataFrame(wksh.get_all_records())
# Remove excess information
# TODO : implement a way to automatically determine what the last entry is.
tot_entries = 9
df = df.iloc[:tot_entries]

# %%
df
# Out:
#                   Company Name  \
# 0                  Neat Coffee
# 1              Moongoat Coffee
# 2                 Nüdae Coffee
# 3  Lion & Lamb Coffee Roasters
# 4             Work in Progress
# 5                In-sīt Coffee
# 6                Buenas Coffee
# 7      Portola Coffee Roasters
# 8                 Philz Coffee
#
#                                              Address    Phone Number  \
# 0              1922 Pomona Ave, Costa Mesa, CA 92627  (949) 873-6328
# 1           1985 Placentia Ave, Costa Mesa, CA 92627  (949) 612-2875
# 2         1125 Victoria St # U, Costa Mesa, CA 92627  (408) 667-9051
# 3              3186 Pullman St, Costa Mesa, CA 92626
# 4         2944 Randolph Av # 1, Costa Mesa, CA 92626
# 5             891 Baker St B19, Costa Mesa, CA 92626  (714) 852-3040
# 6  150 Paularino Ave Building B, Costa Mesa, CA 9...
# 7       3313 Hyland Ave STE B2, Costa Mesa, CA 92626  (714) 656-7996
# 8              3420 Bristol St, Costa Mesa, CA 92626  (714) 486-2731
#
#                           Website                                 Instagram  \
# 0        https://www.neat.coffee/    https://www.instagram.com/neat.coffee/
# 1                 moongoat.online  https://www.instagram.com/moongoatcoffee
# 2    https://www.nudaecoffee.com/    https://www.instagram.com/nudaecoffee/
# 3  https://lionandlambcoffee.com/       www.instagram.com/lionandlambcoffee
# 4       https://www.wipgoods.com/       https://www.instagram.com/wipgoods/
# 5    https://www.insitcoffee.com/    https://www.instagram.com/insit_coffee
# 6      https://www.buenas.coffee/   https://www.instagram.com/buenas.coffee
# 7  https://www.portolacoffee.com/   https://www.instagram.com/portolacoffee
# 8        https://philzcoffee.com/     https://www.instagram.com/philzcoffee
#
#                Food Menu Table Seating Wifi       Outlets  Parking
# 0  Hot food, Baked goods           Yes  Yes           Yes      Yes
# 1  Hot food, Baked goods           Yes  Yes           Yes  Limited
# 2  Hot food, Baked goods       Limited  Yes           Yes      Yes
# 3  Hot food, Baked goods           Yes  Yes           Yes      Yes
# 4  Hot food, Baked goods       Limited  Yes  Very limited  Limited
# 5       Baked goods only  Very limited  Yes  Very limited  Limited
# 6       Baked goods only       Limited  Yes           Yes      Yes
# 7       Baked goods only           Yes  Yes           Yes      Yes
# 8  Hot food, Baked goods           Yes  Yes           Yes      Yes

# %%
# Access Google Maps
gmaps = googlemaps.Client(key=MAPS_API)

# %%
# Function for getting hours given an address
# TODO : implement getting photos, phone number, website as well.
def get_hours(address):
    geocode = gmaps.geocode(address)
    
    places_result = gmaps.places(query='coffee shop', location=(geocode[0]['geometry']['location']['lat'], geocode[0]['geometry']['location']['lng']))
    
    place_id = places_result['results'][0]['place_id']
    place_details = gmaps.place(place_id=place_id, fields=['name', 'formatted_address', 'opening_hours'])
    
    if 'opening_hours' in place_details['result']:
        return(place_details['result']['opening_hours']['weekday_text'])
    else:
        return('Opening hours not available')

# %%
# Using Address, create new column in dataframe from Hours
df['Hours'] = df['Address'].apply(get_hours)

# %%
df
# Out:
#                   Company Name  \
# 0                  Neat Coffee
# 1              Moongoat Coffee
# 2                 Nüdae Coffee
# 3  Lion & Lamb Coffee Roasters
# 4             Work in Progress
# 5                In-sīt Coffee
# 6                Buenas Coffee
# 7      Portola Coffee Roasters
# 8                 Philz Coffee
#
#                                              Address    Phone Number  \
# 0              1922 Pomona Ave, Costa Mesa, CA 92627  (949) 873-6328
# 1           1985 Placentia Ave, Costa Mesa, CA 92627  (949) 612-2875
# 2         1125 Victoria St # U, Costa Mesa, CA 92627  (408) 667-9051
# 3              3186 Pullman St, Costa Mesa, CA 92626
# 4         2944 Randolph Av # 1, Costa Mesa, CA 92626
# 5             891 Baker St B19, Costa Mesa, CA 92626  (714) 852-3040
# 6  150 Paularino Ave Building B, Costa Mesa, CA 9...
# 7       3313 Hyland Ave STE B2, Costa Mesa, CA 92626  (714) 656-7996
# 8              3420 Bristol St, Costa Mesa, CA 92626  (714) 486-2731
#
#                           Website                                 Instagram  \
# 0        https://www.neat.coffee/    https://www.instagram.com/neat.coffee/
# 1                 moongoat.online  https://www.instagram.com/moongoatcoffee
# 2    https://www.nudaecoffee.com/    https://www.instagram.com/nudaecoffee/
# 3  https://lionandlambcoffee.com/       www.instagram.com/lionandlambcoffee
# 4       https://www.wipgoods.com/       https://www.instagram.com/wipgoods/
# 5    https://www.insitcoffee.com/    https://www.instagram.com/insit_coffee
# 6      https://www.buenas.coffee/   https://www.instagram.com/buenas.coffee
# 7  https://www.portolacoffee.com/   https://www.instagram.com/portolacoffee
# 8        https://philzcoffee.com/     https://www.instagram.com/philzcoffee
#
#                Food Menu Table Seating Wifi       Outlets  Parking  \
# 0  Hot food, Baked goods           Yes  Yes           Yes      Yes
# 1  Hot food, Baked goods           Yes  Yes           Yes  Limited
# 2  Hot food, Baked goods       Limited  Yes           Yes      Yes
# 3  Hot food, Baked goods           Yes  Yes           Yes      Yes
# 4  Hot food, Baked goods       Limited  Yes  Very limited  Limited
# 5       Baked goods only  Very limited  Yes  Very limited  Limited
# 6       Baked goods only       Limited  Yes           Yes      Yes
# 7       Baked goods only           Yes  Yes           Yes      Yes
# 8  Hot food, Baked goods           Yes  Yes           Yes      Yes
#
#                                                Hours
# 0  [Monday: 7:00 AM – 4:00 PM, Tuesday: 7:00 AM –...
# 1  [Monday: 6:00 AM – 9:00 PM, Tuesday: 6:00 AM –...
# 2  [Monday: 6:30 AM – 5:00 PM, Tuesday: 6:30 AM –...
# 3  [Monday: 7:00 AM – 5:00 PM, Tuesday: 7:00 AM –...
# 4  [Monday: 7:00 AM – 6:00 PM, Tuesday: 7:00 AM –...
# 5  [Monday: 7:00 AM – 8:00 PM, Tuesday: 7:00 AM –...
# 6  [Monday: 7:00 AM – 4:00 PM, Tuesday: 7:00 AM –...
# 7  [Monday: 7:00 AM – 5:00 PM, Tuesday: 7:00 AM –...
# 8  [Monday: 5:30 AM – 8:00 PM, Tuesday: 5:30 AM –...

# %%
# Connect to PostgreSQL
engine = create_engine(CONN_STR)

# %%
df.to_sql('store_page_info', engine, if_exists= 'replace', index= False)

engine.dispose()
